# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('2006_2017_features.csv')

# %%
df.head()
# Out:
#          date  year  index  N1  N2  N3  N4  N5  N6  S1  color  zodiac   EvO  \
# 0  2006-01-03  2006      1  25  17  38  26  23  24  47   blue     rat   odd
# 1  2006-01-05  2006      2  10  22  46  44   5  38  13    red     dog   odd
# 2  2006-01-08  2006      3  38  26  28  42  10   1  43  green  dragon   odd
# 3  2006-01-10  2006      4  38  39  21  25  36   5   4   blue    goat  even
# 4  2006-01-12  2006      5  15  37  36  24  27  25  35    red     rat   odd
#
#       BS  month
# 0    big      1
# 1  small      1
# 2    big      1
# 3  small      1
# 4    big      1

# %% [markdown]
# * 期数和特码的关系
# * 隔固定期数出特定生肖或者波色或者特码

# %%
df2006 = df[df['year']==2006]

# %%
df2006[df2006['zodiac']=='rat']
# Out:
#            date  year  index  N1  N2  N3  N4  N5  N6  S1  color zodiac  EvO  \
# 0    2006-01-03  2006      1  25  17  38  26  23  24  47   blue    rat  odd
# 4    2006-01-12  2006      5  15  37  36  24  27  25  35    red    rat  odd
# 10   2006-01-26  2006     11  18  22  27  28  43  23  35    red    rat  odd
# 14   2006-02-04  2006     15  41  39  40  34  45  19  23    red    rat  odd
# 37   2006-03-30  2006     38   2  12  33  19  17  30  23    red    rat  odd
# 52   2006-05-04  2006     53  48  46   3  32   2  47  35    red    rat  odd
# 54   2006-05-09  2006     55  26  18  43  24  25  22  23    red    rat  odd
# 61   2006-05-25  2006     62  29  40  38   9  39  27  47   blue    rat  odd
# 76   2006-06-29  2006     77  17  36  19   2   3  13  47   blue    rat  odd
# 101  2006-08-26  2006    102  27  31  43  29  39  36  23    red    rat  odd
# 106  2006-09-07  2006    107   8  15  25  33  48   5  11  green    rat  odd
# ...

# %%
df2006['zodiac'].value_counts()
# Out:
# horse      22
# snake      19
# rat        16
# dragon     15
# rabbit     13
# ox         13
# goat       12
# tiger      11
# rooster    10
# pig         8
# dog         8
# monkey      7
# Name: zodiac, dtype: int64

# %%
df2006['color'].value_counts()
# Out:
# red      56
# blue     56
# green    42
# Name: color, dtype: int64

# %%
df2006[df2006['color']=='green']
# Out:
#            date  year  index  N1  N2  N3  N4  N5  N6  S1  color   zodiac  \
# 2    2006-01-08  2006      3  38  26  28  42  10   1  43  green   dragon
# 7    2006-01-19  2006      8  28  24  26  44  31  47  17  green    horse
# 8    2006-01-21  2006      9  20   1   7  45  40  34  22  green       ox
# 12   2006-01-30  2006     13  21  48  35   9  33  22  43  green   dragon
# 13   2006-02-02  2006     14  37  20   4  23   5   3  38  green  rooster
# 15   2006-02-07  2006     16   5  40  41  24  15  12  44  green   rabbit
# 18   2006-02-14  2006     19  43   7  34  32  42  22   6  green    snake
# 35   2006-03-25  2006     36  36  43  42  32  45  26  44  green   rabbit
# 38   2006-04-02  2006     39  12  29  39   8  25  45  44  green   rabbit
# 40   2006-04-07  2006     41  29  35  11  10  16  30  28  green     goat
# 42   2006-04-11  2006     43  41   5  26  21  30  36  17  green    horse
# 48   2006-04-25  2006     49   2  32  24  29  26  33   6  green    snake
# ...

# %%
df2006['EvO'].value_counts()
# Out:
# odd     79
# even    75
# Name: EvO, dtype: int64

# %%
df2006['BS'].value_counts()
# Out:
# small    79
# big      75
# Name: BS, dtype: int64
